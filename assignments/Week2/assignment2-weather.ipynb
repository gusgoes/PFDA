# %% [markdown]
# ## Week 02
#
# ***
#
# ### Create a jupyter notebook called assignment2-weather.ipynb that has a nice plot of the temperature over time ( "dryBulbTemperature_Celsius" ).

# %%
#%pip install pandas matplotlib numpy

import pandas as pd # type: ignore
import csv
import numpy as np # type: ignore
import matplotlib.pyplot as plt # type: ignore
import matplotlib.dates as mdates # type: ignore

weatherdata = pd.read_csv('C:/Users/gusgo/PFDA/PFDA/assignments/week2/weatherreadings1.csv', header=0)  # read the data from the csv file

weatherdata
# Out:
#                                   siteId        reportStartDateTime  \
# 0   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:15:00+00:00
# 1   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:45:00+00:00
# 2   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:00:00+00:00
# 3   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:15:00+00:00
# 4   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:30:00+00:00
# ..                                   ...                        ...
# 84  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:00:00+00:00
# 85  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:15:00+00:00
# 86  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:30:00+00:00
# 87  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:45:00+00:00
# 88  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T15:00:00+00:00
#
#             reportEndDateTime  collectionName  isPublic  isLatestVersion  \
# 0   2024-10-02T16:15:00+00:00               1      True             True
# ...

# %% [markdown]
# Inspect Data

# %%
weatherdata.iloc[0]
# Out:
# siteId                            f2d42aea-f516-ec11-b76a-0003ff599499
# reportStartDateTime                          2024-10-02T16:15:00+00:00
# reportEndDateTime                            2024-10-02T16:15:00+00:00
# collectionName                                                       1
# isPublic                                                          True
# isLatestVersion                                                   True
# observationType                                                      1
# softwareType                                               WeatherLink
# windDirection                                                      322
# relativeHumidity                                                  70.4
# windSpeed_MilePerHour                                             3.06
# windSpeed_MetrePerSecond                                       1.36794
# dryBulbTemperature_Fahrenheit                                     60.7
# ...

# %%
weatherdata['dryBulbTemperature_Celsius'].value_counts()
# Out:
# dryBulbTemperature_Celsius
# 10.833333    8
# 10.722222    5
# 14.944444    3
# 10.666667    3
# 11.000000    3
# 10.277778    3
# 10.777778    3
# 12.500000    2
# 10.333333    2
# 9.833333     2
# 9.444444     2
# 9.500000     2
# 10.000000    2
# 11.944444    2
# 13.666667    2
# 11.222222    2
# 13.000000    2
# 14.666667    2
# 14.555556    2
# 11.111111    2
# 14.722222    2
# 9.888889     2
# 14.611111    1
# 14.777778    1
# 13.555556    1
# 10.500000    1
# 13.277778    1
# 12.722222    1
# 14.500000    1
# 12.666667    1
# 14.111111    1
# 12.222222    1
# 11.611111    1
# 11.388889    1
# 13.833333    1
# 15.944444    1
# 10.444444    1
# 10.055556    1
# 15.111111    1
# 14.277778    1
# 13.222222    1
# 11.500000    1
# 10.555556    1
# 10.222222    1
# 9.944444     1
# 10.111111    1
# 9.777778     1
# 15.777778    1
# 9.166667     1
# 9.555556     1
# 9.722222     1
# 9.388889     1
# 9.222222     1
# Name: count, dtype: int64

# %%
weatherdata.describe()
# Out:
#        collectionName  observationType  windDirection  relativeHumidity  \
# count            89.0             89.0      89.000000         89.000000
# mean              1.0              1.0     188.292135         85.135955
# std               0.0              0.0     144.536579          5.626101
# min               1.0              1.0       0.000000         70.400000
# 25%               1.0              1.0      40.000000         79.900000
# 50%               1.0              1.0     275.000000         87.200000
# 75%               1.0              1.0     333.000000         89.400000
# max               1.0              1.0     359.000000         92.400000
#
#        windSpeed_MilePerHour  windSpeed_MetrePerSecond  \
# count              89.000000                 89.000000
# mean                2.866067                  1.281245
# std                 2.637010                  1.178847
# min                 0.000000                  0.000000
# ...

# %%
temp_drycelsius = weatherdata[['reportStartDateTime', 'dryBulbTemperature_Celsius']]
temp_drycelsius
# Out:
#           reportStartDateTime  dryBulbTemperature_Celsius
# 0   2024-10-02T16:15:00+00:00                   15.944444
# 1   2024-10-02T16:45:00+00:00                   15.777778
# 2   2024-10-02T17:00:00+00:00                   15.111111
# 3   2024-10-02T17:15:00+00:00                   14.277778
# 4   2024-10-02T17:30:00+00:00                   13.666667
# ..                        ...                         ...
# 84  2024-10-03T14:00:00+00:00                   14.611111
# 85  2024-10-03T14:15:00+00:00                   14.944444
# 86  2024-10-03T14:30:00+00:00                   14.944444
# 87  2024-10-03T14:45:00+00:00                   14.944444
# 88  2024-10-03T15:00:00+00:00                   14.722222
#
# [89 rows x 2 columns]

# %% [markdown]
# Line Plot

# %%
plt.figure(figsize=(10, 6))
plt.plot(temp_drycelsius['reportStartDateTime'], temp_drycelsius['dryBulbTemperature_Celsius'], marker='o')
plt.title('Dry Bulb Temperature Over Time')
plt.xlabel('DateTime')
plt.ylabel('Dry Bulb Temperature (°C)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(temp_drycelsius['reportStartDateTime'], temp_drycelsius['dryBulbTemperature_Celsius'], marker='o')
plt.title('Dry Bulb Temperature Over Time')
plt.xlabel('DateTime')
plt.ylabel('Dry Bulb Temperature (°C)')
plt.grid(True)

ax = plt.gca()
ax.xaxis.set_major_locator(mdates.DayLocator(interval=5))  # Set major ticks to every day
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))  # Format major ticks as 'YYYY-MM-DD'
ax.xaxis.set_minor_locator(mdates.HourLocator(interval=6))  # Set minor ticks to every 6 hours

plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# Scatter Plot

# %%
plt.figure(figsize=(10, 6))
plt.scatter(temp_drycelsius['reportStartDateTime'], temp_drycelsius['dryBulbTemperature_Celsius'])
plt.title('Dry Bulb Temperature Over Time')
plt.xlabel('DateTime')
plt.ylabel('Dry Bulb Temperature (°C)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(temp_drycelsius['reportStartDateTime'], temp_drycelsius['dryBulbTemperature_Celsius'], marker='o')
plt.title('Dry Bulb Temperature Over Time')
plt.xlabel('DateTime')
plt.ylabel('Dry Bulb Temperature (°C)')
plt.grid(True)

# Set major and minor ticks format and interval
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.DayLocator(interval=5))  # Set major ticks to every day
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))  # Format major ticks as 'YYYY-MM-DD'
ax.xaxis.set_minor_locator(mdates.HourLocator(interval=6))  # Set minor ticks to every 6 hours

plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(temp_drycelsius['dryBulbTemperature_Celsius'], bins=20, edgecolor='black')
plt.title('Distribution of Dry Bulb Temperature')
plt.xlabel('Dry Bulb Temperature (°C)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(temp_drycelsius['dryBulbTemperature_Celsius'], vert=False)
plt.title('Box Plot of Dry Bulb Temperature')
plt.xlabel('Dry Bulb Temperature (°C)')
plt.grid(True)
plt.show()

# %% [markdown]
# ***
# ## Resource
#
# PROGRAMMING AND SCRIPTING - 2024/1 - Final Project
#
# ***
# # End
# ***
