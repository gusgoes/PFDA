# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.random.uniform(0, 1, 10000)
plt.hist(x)
# Out:
# (array([1010., 1023.,  976., 1005.,  988., 1007.,  988., 1009., 1019.,
#          975.]),
#  array([3.98940091e-04, 1.00346176e-01, 2.00293411e-01, 3.00240647e-01,
#         4.00187883e-01, 5.00135118e-01, 6.00082354e-01, 7.00029590e-01,
#         7.99976825e-01, 8.99924061e-01, 9.99871296e-01]),
#  <BarContainer object of 10 artists>)
