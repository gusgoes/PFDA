# %%
# this is code for for the quiz
import re

regex = "^Hello [A-Z]"
#regex = "hello" #a
#regex = "Hello" #b
#regex = "^Hello" #c
#regex = "^Hell*o" #d
#regex = "^Hell+o" #e
#regex = "^Hell?o" #f
#regex = "^hello [A-Z]" #g
#regex = "^Hello [A-Z]" #h
#regex = "=" #i
#regex = "#" #j
#regex = "[" #k
#regex = "^$" #l
filename = "C:\\Users\\gusgo\\OneDrive - Atlantic TU\\PFDA\labs\\week4\\quiz.txt"

with open(filename) as quizFile:
    for line in quizFile:
        searchResult = re.search(regex, line)
        if (searchResult):
            matchingLine = line
            print (matchingLine, end="")
# Out:
# var = 123
